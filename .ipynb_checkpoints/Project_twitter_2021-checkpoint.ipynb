# %% [markdown]
# # Twitter analytics project

# %%
pip install ConfigParser
# Out:
# Collecting ConfigParser
#   Downloading configparser-5.0.2-py3-none-any.whl (19 kB)
# Installing collected packages: ConfigParser
# Successfully installed ConfigParser-5.0.2
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import ConfigParser
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c4bf5d3ef049> in <module>
# ----> 1 import ConfigParser
#
# ModuleNotFoundError: No module named 'ConfigParser'

# %%
import tweepy
import json


# 4 cadenas para la autenticacion

consumer_key="Pc8A74Nn1xgGNWfcy1vt7lrKJ"
consumer_secret="A65nyRJcGbeTEPC7mlqy2W7csdVuQBqQlJjDRSkb1LVHJHoDmb"
access_token ="162263270-OAQ5Kiik3HcAcjND7TUEzHfVYCTIF2MslDUoBR3L"
access_token_secret = "RtYtDJn5RyYnRPf4okQHpFjv4pZCJ1wbo3GvfPdi5FJ2r"

auth= tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)


api= tweepy.API(auth, wait_on_rate_limit=True,
	wait_on_rate_limit_notify=True)
tweets=api.search("Disney", count=100)

# %%
import re
import pandas as pd
from textblob import TextBlob
#create a dataframe
df=pd.DataFrame(columns=('tweet_text', 'tweet_sentiment', 'tweet_subjectivity',
							'user_followers_count','user_friends_count',
							'user_account_age', 'user_verified',
							'user_favourites_count', 'user_tweets',
							'tweet_retweeted', 'tweet_retweet_count', 'tweet_favorite_count'))
#Remove duplicates

df.sort_values('tweet_text', inplace=True)
df.drop_duplicates(subset="tweet_text", keep=False, inplace=True)
# Out:
# Empty DataFrame
# Columns: [tweet_text, tweet_sentiment, tweet_subjectivity, user_followers_count, user_friends_count, user_account_age, user_verified, user_favourites_count, user_tweets, tweet_retweeted, tweet_retweet_count, tweet_favorite_count]
# Index: []

# %%
for tweet in tweets:
	sentimentText=TextBlob(tweet.text)
	df=df.append({'tweet_text':re.sub(r'http\S+','', tweet.text), 
				 'tweet_sentiment':sentimentText.sentiment.polarity, 
				 'tweet_subjectivity': sentimentText.sentiment.subjectivity,
				'user_followers_count': tweet.user.followers_count,
				'user_friends_count': tweet.user.friends_count,
				'user_account_age': tweet.user.created_at, 
				'user_verified': tweet.user.verified,
				'user_favourites_count':tweet.user.favourites_count,
				'user_tweets': tweet.user.statuses_count,
				'tweet_retweeted': tweet.retweeted,
				'tweet_retweet_count': tweet.retweet_count, 
				'tweet_favorite_count': tweet.favorite_count},
				ignore_index=True)

# %%
df.head()
# Out:
#                                           tweet_text  tweet_sentiment  \
# 0  @BruzundangaR Onde já se viu, empregada domést...         0.000000
# 1  RT @milesholy: ✨finalizando el hilo añado que ...         0.000000
# 2  RT @DisneyFoodBlog: Check Out the BRAND NEW St...         0.170455
# 3  @SagexM1x3rr @MaZ_f15 You can watch the traile...         0.000000
# 4  RT @mefeater: 19 years ago The Proud Family pr...         0.650000
#
#    tweet_subjectivity user_followers_count user_friends_count  \
# 0            0.000000                 1397                884
# 1            0.000000                  476                701
# 2            0.454545                  145                112
# 3            0.000000                   21                125
# 4            0.750000                  377                301
#
#      user_account_age user_verified user_favourites_count user_tweets  \
# 0 2010-08-18 18:58:37         False                194310       79056
# 1 2013-10-13 14:41:50         False                 36272       38589
# 2 2016-01-13 21:34:48         False                 81786       82426
# 3 2019-07-20 05:23:40         False                  1586        2450
# 4 2018-01-13 20:16:39         False                 13793       15539
#
#   tweet_retweeted tweet_retweet_count tweet_favorite_count
# 0           False                   0                    0
# 1           False                   7                    0
# 2           False                   1                    0
# 3           False                   0                    0
# 4           False                1316                    0

# %%
#tweet length

df['tweet_text_length']=df['tweet_text'].apply(lambda x: len(x) - x.count(" "))

#Count of punctuation in the tweet

import string

def count_punc(text):
	count = sum ([1 for char in text if char in string.punctuation])
	return count
df['tweet_text_punc_count']= df['tweet_text'].apply(lambda x: count_punc(x))

df.head()
# Out:
#                                           tweet_text  tweet_sentiment  \
# 0  @BruzundangaR Onde já se viu, empregada domést...         0.000000
# 1  RT @milesholy: ✨finalizando el hilo añado que ...         0.000000
# 2  RT @DisneyFoodBlog: Check Out the BRAND NEW St...         0.170455
# 3  @SagexM1x3rr @MaZ_f15 You can watch the traile...         0.000000
# 4  RT @mefeater: 19 years ago The Proud Family pr...         0.650000
#
#    tweet_subjectivity user_followers_count user_friends_count  \
# 0            0.000000                 1397                884
# 1            0.000000                  476                701
# 2            0.454545                  145                112
# 3            0.000000                   21                125
# 4            0.750000                  377                301
#
#      user_account_age user_verified user_favourites_count user_tweets  \
# 0 2010-08-18 18:58:37         False                194310       79056
# 1 2013-10-13 14:41:50         False                 36272       38589
# 2 2016-01-13 21:34:48         False                 81786       82426
# 3 2019-07-20 05:23:40         False                  1586        2450
# 4 2018-01-13 20:16:39         False                 13793       15539
#
#   tweet_retweeted tweet_retweet_count tweet_favorite_count  tweet_text_length  \
# 0           False                   0                    0                 68
# 1           False                   7                    0                116
# 2           False                   1                    0                 90
# 3           False                   0                    0                 57
# 4           False                1316                    0                100
#
#    tweet_text_punc_count
# 0                      5
# 1                      2
# 2                      4
# 3                      3
# 4                      4

# %%
df1=df.head(10)
df1
# Out:
#                                           tweet_text  tweet_sentiment  \
# 0  @BruzundangaR Onde já se viu, empregada domést...         0.000000
# 1  RT @milesholy: ✨finalizando el hilo añado que ...         0.000000
# 2  RT @DisneyFoodBlog: Check Out the BRAND NEW St...         0.170455
# 3  @SagexM1x3rr @MaZ_f15 You can watch the traile...         0.000000
# 4  RT @mefeater: 19 years ago The Proud Family pr...         0.650000
# 5  RT @Astro_Latte: @bangbangbeefke1 You know how...         0.800000
# 6  .@ZacharyFaria says @JakeTapper is on a roll a...         0.000000
# 7  RT @mefeater: 19 years ago The Proud Family pr...         0.650000
# 8  RT @mefeater: 19 years ago The Proud Family pr...         0.650000
# 9  @wit_ace Bota eu e vc lá q eles vão ver oq é i...         0.000000
#
#    tweet_subjectivity user_followers_count user_friends_count  \
# 0            0.000000                 1397                884
# 1            0.000000                  476                701
# 2            0.454545                  145                112
# 3            0.000000                   21                125
# 4            0.750000                  377                301
# 5            0.700000                  620                394
# 6            0.000000               265465                246
# 7            0.750000                 1093                643
# 8            0.750000                  127                310
# 9            0.000000                  652                228
#
#      user_account_age user_verified user_favourites_count user_tweets  \
# 0 2010-08-18 18:58:37         False                194310       79056
# 1 2013-10-13 14:41:50         False                 36272       38589
# 2 2016-01-13 21:34:48         False                 81786       82426
# 3 2019-07-20 05:23:40         False                  1586        2450
# 4 2018-01-13 20:16:39         False                 13793       15539
# 5 2020-02-06 20:33:05         False                 15812        6646
# 6 2009-01-13 22:16:00          True                   672      491501
# 7 2014-06-21 11:51:30         False                  6698      140210
# 8 2018-06-26 03:14:04         False                  7117       30372
# 9 2017-06-09 17:40:44         False                  3838        1279
#
#   tweet_retweeted tweet_retweet_count tweet_favorite_count  tweet_text_length  \
# 0           False                   0                    0                 68
# 1           False                   7                    0                116
# 2           False                   1                    0                 90
# 3           False                   0                    0                 57
# 4           False                1316                    0                100
# 5           False                   1                    0                119
# 6           False                   0                    0                 99
# 7           False                1316                    0                100
# 8           False                1316                    0                100
# 9           False                   0                    0                 49
#
#    tweet_text_punc_count
# 0                      5
# 1                      2
# 2                      4
# 3                      3
# 4                      4
# 5                      7
# 6                      6
# 7                      4
# 8                      4
# 9                      2

# %% [markdown]
# ### Watson

# %%
import json
import numpy as np
import pandas as pd

from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, EmotionOptions, SentimentOptions


service= NaturalLanguageUnderstandingV1(
    version='2018-11-16',
    iam_apikey='h4GvFiqdAP0RDZumUw57ufFMz2UzlcUluW8K7tiurBkL',
    url='https://api.eu-gb.natural-language-understanding.watson.cloud.ibm.com/instances/122a22f4-6028-4995-9d41-136f4b49ce1d')


def analisis_watson(text):
    text = text.decode("utf-8")
    print(text)
    response = service.analyze(
        text=text,features=Features(emotion=EmotionOptions(), sentiment=SentimentOptions()))
    return response
# Out:
# /Users/paulakoch/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.
#   if sys.path[0] == '':

# %%
def sentiment_and_keyword(st,service=service):
    return (service.analyze(text=st,features=Features(emotion=EmotionOptions(),
                                                      sentiment=SentimentOptions())).get_result())

# %%
df1['sentiment_keyword_json'] = df1.apply(lambda row : sentiment_and_keyword(str(row['tweet_text'])),axis = 1)
# Out:
# /Users/paulakoch/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def sentiment_extractor(row_num):
    sentiment_scores=df1['sentiment_keyword_json'][row_num]['sentiment']['document']
    return sentiment_scores

# %%
df1['sentiment_score'] = df1.apply(lambda row : sentiment_extractor(row.name),axis = 1)
# Out:
# /Users/paulakoch/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#                                           tweet_text  tweet_sentiment  \
# 0  @BruzundangaR Onde já se viu, empregada domést...         0.000000
# 1  RT @milesholy: ✨finalizando el hilo añado que ...         0.000000
# 2  RT @DisneyFoodBlog: Check Out the BRAND NEW St...         0.170455
# 3  @SagexM1x3rr @MaZ_f15 You can watch the traile...         0.000000
# 4  RT @mefeater: 19 years ago The Proud Family pr...         0.650000
# 5  RT @Astro_Latte: @bangbangbeefke1 You know how...         0.800000
# 6  .@ZacharyFaria says @JakeTapper is on a roll a...         0.000000
# 7  RT @mefeater: 19 years ago The Proud Family pr...         0.650000
# 8  RT @mefeater: 19 years ago The Proud Family pr...         0.650000
# 9  @wit_ace Bota eu e vc lá q eles vão ver oq é i...         0.000000
#
#    tweet_subjectivity user_followers_count user_friends_count  \
# 0            0.000000                 1397                884
# 1            0.000000                  476                701
# 2            0.454545                  145                112
# 3            0.000000                   21                125
# 4            0.750000                  377                301
# 5            0.700000                  620                394
# 6            0.000000               265465                246
# 7            0.750000                 1093                643
# 8            0.750000                  127                310
# 9            0.000000                  652                228
#
#      user_account_age user_verified user_favourites_count user_tweets  \
# 0 2010-08-18 18:58:37         False                194310       79056
# 1 2013-10-13 14:41:50         False                 36272       38589
# 2 2016-01-13 21:34:48         False                 81786       82426
# 3 2019-07-20 05:23:40         False                  1586        2450
# 4 2018-01-13 20:16:39         False                 13793       15539
# 5 2020-02-06 20:33:05         False                 15812        6646
# 6 2009-01-13 22:16:00          True                   672      491501
# 7 2014-06-21 11:51:30         False                  6698      140210
# 8 2018-06-26 03:14:04         False                  7117       30372
# 9 2017-06-09 17:40:44         False                  3838        1279
#
#   tweet_retweeted tweet_retweet_count tweet_favorite_count  tweet_text_length  \
# 0           False                   0                    0                 68
# 1           False                   7                    0                116
# 2           False                   1                    0                 90
# 3           False                   0                    0                 57
# 4           False                1316                    0                100
# 5           False                   1                    0                119
# 6           False                   0                    0                 99
# 7           False                1316                    0                100
# 8           False                1316                    0                100
# 9           False                   0                    0                 49
#
#    tweet_text_punc_count                             sentiment_keyword_json  \
# 0                      5  {'usage': {'text_units': 1, 'text_characters':...
# 1                      2  {'usage': {'text_units': 1, 'text_characters':...
# 2                      4  {'usage': {'text_units': 1, 'text_characters':...
# 3                      3  {'usage': {'text_units': 1, 'text_characters':...
# 4                      4  {'usage': {'text_units': 1, 'text_characters':...
# 5                      7  {'usage': {'text_units': 1, 'text_characters':...
# 6                      6  {'usage': {'text_units': 1, 'text_characters':...
# 7                      4  {'usage': {'text_units': 1, 'text_characters':...
# 8                      4  {'usage': {'text_units': 1, 'text_characters':...
# 9                      2  {'usage': {'text_units': 1, 'text_characters':...
#
#                              sentiment_score
# 0   {'score': 0.494782, 'label': 'positive'}
# 1   {'score': 0.842895, 'label': 'positive'}
# 2           {'score': 0, 'label': 'neutral'}
# 3           {'score': 0, 'label': 'neutral'}
# 4   {'score': 0.957179, 'label': 'positive'}
# 5           {'score': 0, 'label': 'neutral'}
# 6   {'score': 0.332597, 'label': 'positive'}
# 7   {'score': 0.957179, 'label': 'positive'}
# 8   {'score': 0.957179, 'label': 'positive'}
# 9  {'score': -0.622478, 'label': 'negative'}
